# %%
# Install the Kaggle package for accessing datasets
# !pip install kaggle

# %%
#Import the files module from Google Colab and upload the kaggle.json file
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-44a97fb2-9c3c-4396-a97f-9fb5e980e2de" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-44a97fb2-9c3c-4396-a97f-9fb5e980e2de">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Create the .kaggle directory, move kaggle.json to it, and set file permissions to ensure security
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d harshvir04/cleaned-google-play-store-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/harshvir04/cleaned-google-play-store-dataset
# License(s): apache-2.0
# ...
#   0% 0.00/330k [00:00<?, ?B/s]
# 100% 330k/330k [00:00<00:00, 81.4MB/s]

# %%
#Unzip the cleaned Google Play Store dataset file
# !unzip cleaned-google-play-store-dataset
# Out:
# Archive:  cleaned-google-play-store-dataset.zip
#   inflating: google_cleaned (2).csv

# %%
#Read the dataset
import pandas as pd
df = pd.read_csv('/content/google_cleaned (2).csv')

# %%
#Check the dimensions of dataframe
df.shape
# Out:
# (10840, 16)

# %%
#Look for the first few rows of the dataset
df.head()
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1                                Coloring book moana
# 2           2  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3           3                              Sketch - Draw & Paint
# 4           4              Pixel Draw - Number Art Coloring Book
#
#          Category  Rating  Reviews     Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19000.0     10000  Free    0.0
# 1  ART_AND_DESIGN     3.9      967  14000.0    500000  Free    0.0
# 2  ART_AND_DESIGN     4.7    87510   8700.0   5000000  Free    0.0
# 3  ART_AND_DESIGN     4.5   215644  25000.0  50000000  Free    0.0
# 4  ART_AND_DESIGN     4.3      967   2800.0    100000  Free    0.0
#
#   Content Rating                     Genres         Current Ver   Android Ver  \
# 0       Everyone               Art & Design               1.0.0  4.0.3 and up
# ...
